# %% [markdown]
# # SatQuery AI — API on this Kaggle GPU
#
# Before running: **Settings → Accelerator: GPU T4 x2**, **Internet: On**, and **Add-ons → Secrets → `HF_TOKEN`** (a Hugging Face *read* token; the trained checkpoints live in a private model repo).
#
# Run the cell below. It installs the stack, downloads the base model and checkpoints, load-checks all 8 tools, starts the API on the T4 and opens a public HTTPS tunnel. It prints the API URL and a frontend link of the form `https://satquery-ai-self.vercel.app/query?api=<url>`. Keep the cell running; stop it to end the session.

# %%
# !git clone --depth 1 https://github.com/aditya-coder07/SatQuery_AI.git /kaggle/working/satquery 2>/dev/null || (cd /kaggle/working/satquery && git pull -q)
# %run /kaggle/working/satquery/deploy/kaggle/satquery_kaggle.py
